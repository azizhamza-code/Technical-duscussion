# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzaazi/Technical-duscussion/blob/main/technical-docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Notebook is a great way to share idea and  code
### for ex this is a forme of a data project

# %% [markdown]
# # Ingest

# %%
#@title Example form fields
#@markdown Forms support many types of fields.

no_type_checking = ''  #@param
string_type = 'example'  #@param {type: "string"}
slider_value = 142  #@param {type: "slider", min: 100, max: 200}
number = 102  #@param {type: "number"}
date = '2010-11-05'  #@param {type: "date"}
pick_me = "monday"  #@param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" #@param ["apples", "bananas", "oranges"] {allow-input: true}
#@markdown ---

# %%
def hello():

  return 'hi'

hello()
# Out:
# 'hi'

# %% [markdown]
# # EDA

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **this is the power of markdown is we can re-use it**
#
# 1. one
# 2. two
# 3. three

# %% [markdown]
# # Modeling

# %% [markdown]
# # Conclusion
